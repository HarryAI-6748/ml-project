# %% [markdown]
# <a href="https://colab.research.google.com/github/HarryAI-6748/ml-project/blob/main/pandas_aiml_hindi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/mckinsey (1).csv')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.size
# Out:
# 10224

# %%
df.ndim
# Out:
# 2

# %%
df.head(10) # top rows
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.tail(7)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df['country'].values
# Out:
# array(['Afghanistan', 'Afghanistan', 'Afghanistan', ..., 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe'], dtype=object)

# %%
df.values
# Out:
# array([['Afghanistan', 1952, 8425333, 'Asia', 28.801, 779.4453145],
#        ['Afghanistan', 1957, 9240934, 'Asia', 30.332, 820.8530296],
#        ['Afghanistan', 1962, 10267083, 'Asia', 31.997, 853.10071],
#        ...,
#        ['Zimbabwe', 1997, 11404948, 'Africa', 46.809, 792.4499603],
#        ['Zimbabwe', 2002, 11926563, 'Africa', 39.989, 672.0386227],
#        ['Zimbabwe', 2007, 12311143, 'Africa', 43.487, 469.7092981]],
#       dtype=object)

# %%
df['life_exp']
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
x = pd.Series([10,20,30])
x > 15
# Out:
# 0    False
# 1     True
# 2     True
# dtype: bool

# %%
# masking
# x[[False,True,True]]
x[x>15]
# Out:
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series([10,'Pulkit',30]) # '10'
# Out:
# 0        10
# 1    Pulkit
# 2        30
# dtype: object

# %%
# create a new column

df['gdp'] = df['population'] * df['gdp_cap']
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap           gdp
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086e+09
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449e+09
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856e+09
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014e+09
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553e+09

# %%
df['year'] = df['year'] + 3

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap           gdp
# 0  Afghanistan  1955     8425333      Asia    28.801  779.445314  6.567086e+09
# 1  Afghanistan  1960     9240934      Asia    30.332  820.853030  7.585449e+09
# 2  Afghanistan  1965    10267083      Asia    31.997  853.100710  8.758856e+09
# 3  Afghanistan  1970    11537966      Asia    34.020  836.197138  9.648014e+09
# 4  Afghanistan  1975    13079460      Asia    36.088  739.981106  9.678553e+09

# %%
# filter: indexing
df['year'][2]
# Out:
# np.int64(1965)

# %%
condition =  df['year'] == 1955 # comparison output is boolean series
df[condition]
# Out:
#                  country  year  population continent  life_exp      gdp_cap  \
# 0            Afghanistan  1955     8425333      Asia    28.801   779.445314
# 12               Albania  1955     1282697    Europe    55.230  1601.056136
# 24               Algeria  1955     9279525    Africa    43.077  2449.008185
# 36                Angola  1955     4232095    Africa    30.015  3520.610273
# 48             Argentina  1955    17876956  Americas    62.485  5911.315053
# ...                  ...   ...         ...       ...       ...          ...
# 1644             Vietnam  1955    26246839      Asia    40.412   605.066492
# 1656  West Bank and Gaza  1955     1030585      Asia    43.160  1515.592329
# 1668         Yemen, Rep.  1955     4963829      Asia    32.548   781.717576
# 1680              Zambia  1955     2672000    Africa    42.038  1147.388831
# 1692            Zimbabwe  1955     3080907    Africa    48.451   406.884115
#
#                gdp
# 0     6.567086e+09
# ...

# %%
df[df['year'] == 1955]
# Out:
#                  country  year  population continent  life_exp      gdp_cap  \
# 0            Afghanistan  1955     8425333      Asia    28.801   779.445314
# 12               Albania  1955     1282697    Europe    55.230  1601.056136
# 24               Algeria  1955     9279525    Africa    43.077  2449.008185
# 36                Angola  1955     4232095    Africa    30.015  3520.610273
# 48             Argentina  1955    17876956  Americas    62.485  5911.315053
# ...                  ...   ...         ...       ...       ...          ...
# 1644             Vietnam  1955    26246839      Asia    40.412   605.066492
# 1656  West Bank and Gaza  1955     1030585      Asia    43.160  1515.592329
# 1668         Yemen, Rep.  1955     4963829      Asia    32.548   781.717576
# 1680              Zambia  1955     2672000    Africa    42.038  1147.388831
# 1692            Zimbabwe  1955     3080907    Africa    48.451   406.884115
#
#                gdp
# 0     6.567086e+09
# ...

# %%
df[df['year'] >= 2000]
# Out:
#           country  year  population continent  life_exp      gdp_cap  \
# 9     Afghanistan  2000    22227415      Asia    41.763   635.341351
# 10    Afghanistan  2005    25268405      Asia    42.129   726.734055
# 11    Afghanistan  2010    31889923      Asia    43.828   974.580338
# 21        Albania  2000     3428038    Europe    72.950  3193.054604
# 22        Albania  2005     3508512    Europe    75.651  4604.211737
# ...           ...   ...         ...       ...       ...          ...
# 1690       Zambia  2005    10595811    Africa    39.193  1071.613938
# 1691       Zambia  2010    11746035    Africa    42.384  1271.211593
# 1701     Zimbabwe  2000    11404948    Africa    46.809   792.449960
# 1702     Zimbabwe  2005    11926563    Africa    39.989   672.038623
# 1703     Zimbabwe  2010    12311143    Africa    43.487   469.709298
#
#                gdp
# 9     1.412200e+10
# 10    1.836341e+10
# 11    3.107929e+10
# 21    1.094591e+10
# 22    1.615393e+10
# ...

# %%
df[df['continent'] == 'Europe']
# Out:
#              country  year  population continent  life_exp       gdp_cap  \
# 12           Albania  1955     1282697    Europe    55.230   1601.056136
# 13           Albania  1960     1476505    Europe    59.280   1942.284244
# 14           Albania  1965     1728137    Europe    64.820   2312.888958
# 15           Albania  1970     1984060    Europe    66.220   2760.196931
# 16           Albania  1975     2263554    Europe    67.690   3313.422188
# ...              ...   ...         ...       ...       ...           ...
# 1603  United Kingdom  1990    56981620    Europe    75.007  21664.787670
# 1604  United Kingdom  1995    57866349    Europe    76.420  22705.092540
# 1605  United Kingdom  2000    58808266    Europe    77.218  26074.531360
# 1606  United Kingdom  2005    59912431    Europe    78.471  29478.999190
# 1607  United Kingdom  2010    60776238    Europe    79.425  33203.261280
#
#                gdp
# 12    2.053670e+09
# 13    2.867792e+09
# 14    3.996989e+09
# ...

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap           gdp
# count  1704.00000  1.704000e+03  1704.000000    1704.000000  1.704000e+03
# mean   1982.50000  2.960121e+07    59.474439    7215.327081  1.868096e+11
# std      17.26533  1.061579e+08    12.917107    9857.454543  7.140297e+11
# min    1955.00000  6.001100e+04    23.599000     241.165876  5.278469e+07
# 25%    1968.75000  2.793664e+06    48.198000    1202.060309  5.895295e+09
# 50%    1982.50000  7.023596e+06    60.712500    3531.846988  2.234330e+10
# 75%    1996.25000  1.958522e+07    70.845500    9325.462346  1.057441e+11
# max    2010.00000  1.318683e+09    82.603000  113523.132900  1.293446e+13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
#  6   gdp         1704 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 93.3+ KB

# %%
# selecting multiple columns
cols = ['year','life_exp']
df[cols] # filter brackets expect only a single input
# Out:
#       year  life_exp
# 0     1955    28.801
# 1     1960    30.332
# 2     1965    31.997
# 3     1970    34.020
# 4     1975    36.088
# ...    ...       ...
# 1699  1990    62.351
# 1700  1995    60.377
# 1701  2000    46.809
# 1702  2005    39.989
# 1703  2010    43.487
#
# [1704 rows x 2 columns]

# %%
df[['life_exp','year']]
# Out:
#       life_exp  year
# 0       28.801  1955
# 1       30.332  1960
# 2       31.997  1965
# 3       34.020  1970
# 4       36.088  1975
# ...        ...   ...
# 1699    62.351  1990
# 1700    60.377  1995
# 1701    46.809  2000
# 1702    39.989  2005
# 1703    43.487  2010
#
# [1704 rows x 2 columns]

# %%
# multiple filter conditions

df_1955_eur = df[(df['continent'] == 'Europe') & (df['year'] == 1955)]
df_1955_eur
# Out:
#                      country  year  population continent  life_exp  \
# 12                   Albania  1955     1282697    Europe    55.230
# 72                   Austria  1955     6927772    Europe    66.800
# 108                  Belgium  1955     8730405    Europe    68.000
# 144   Bosnia and Herzegovina  1955     2791000    Europe    53.820
# 180                 Bulgaria  1955     7274900    Europe    59.600
# 372                  Croatia  1955     3882229    Europe    61.210
# 396           Czech Republic  1955     9125183    Europe    66.870
# 408                  Denmark  1955     4334000    Europe    70.780
# 516                  Finland  1955     4090500    Europe    66.550
# 528                   France  1955    42459667    Europe    67.410
# 564                  Germany  1955    69145952    Europe    67.500
# 588                   Greece  1955     7733250    Europe    65.860
# 672                  Hungary  1955     9504000    Europe    64.030
# ...

# %%
# country with lowest and highest life exp

df['life_exp'].min()
# Out:
# 23.599

# %%
df[df['life_exp'] == df['life_exp'].min()]
# Out:
#      country  year  population continent  life_exp     gdp_cap           gdp
# 1292  Rwanda  1995     7290203    Africa    23.599  737.068595  5.373380e+09

# %%
df[df['life_exp'] == df['life_exp'].max()]
